# %% [markdown]
# ¡Hola, Salvador!
#
# Mi nombre es Tonatiuh Cruz. Me complace revisar tu proyecto hoy.
#
# Al identificar cualquier error inicialmente, simplemente los destacaré. Te animo a localizar y abordar los problemas de forma independiente como parte de tu preparación para un rol como data-scientist. En un entorno profesional, tu líder de equipo seguiría un enfoque similar. Si encuentras la tarea desafiante, proporcionaré una pista más específica en la próxima iteración.
#
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o elimines**.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo está hecho correctamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con comentarios en rojo.
# </div>
#
# Puedes responderme utilizando esto:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Resumen de la revisión 1</b> <a class="tocSkip"></a>
#
# Hola,Salvador! Has hecho un excelente trabajo al realizar el proyecto, cargaste correctamente la información y la limpieza de esta información. Además, desarrollaste perfectamente el desarrollo del análisis con gráficas e interpretación. Solamente te dejo algunos comentarios para terminar de complementar el análisis.
#
# Sigue con el excelente trabajo!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Resumen de la revisión 2</b> <a class="tocSkip"></a>
#
# Muy buen trabajo verificando la existencia de duplicados en la variable del nombre del producto y usando la función value_counts(). Continúa esforzándote!
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Hola! Excelente trabajo desarrollando la introducción y el diccionario de datos. Esto es crucial para cualquier proyecto, ya que establece una guía clara sobre los pasos a seguir. Tener estos elementos bien definidos desde el principio nos permite trabajar de manera más organizada y eficiente. En un futuro lo podrías complementar con una tabla de contenido.
# </div>

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos. - Importar las librerias, y despues usar .info para observar los detalles de cada archivo.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_orders = pd.read_csv('/datasets/instacart_orders.csv', delimiter=';')
df_products = pd.read_csv('/datasets/products.csv', delimiter=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', delimiter=';')
df_departments = pd.read_csv('/datasets/departments.csv', delimiter=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', delimiter=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabajo con la carga de la información

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
df_order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Salvador, excelente trabajo con el uso de info() para mostrar la información general de las bases con las que vamos a trabajar

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos. -
# Aisle y department solo contienen dos columnas, lo que nos dice que son archivos con pocos datos, mientras que order, products y order_products, contienen varias columnas, diciéndonos que son van a ser datos más complejos de analizar.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.- Primero hay que encontrar y elminar los valores duplicados de los archivos, despues hay que encontar los valores ausentes.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
duplicados = df_orders[df_orders.duplicated()]
print(duplicados.count())
print(duplicados.head(15))
# Out:
# order_id                  15
# user_id                   15
# order_number              15
# order_dow                 15
# order_hour_of_day         15
# days_since_prior_order    13
# dtype: int64
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común? - Los 15 duplicados tienen el mismo order_dow y order_hour_of_day

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
pedidos_miercoles_2am = df_orders[(df_orders['order_dow'] == 3) & (df_orders['order_hour_of_day'] == 2)]

print(pedidos_miercoles_2am.count())
print()
print(pedidos_miercoles_2am.duplicated().sum())
# Out:
# order_id                  121
# user_id                   121
# order_number              121
# order_dow                 121
# order_hour_of_day         121
# days_since_prior_order    114
# dtype: int64
#
# 15

# %% [markdown]
# ¿Qué sugiere este resultado? - Los 15 duplicados encontrados están en los pedidos que se hicieron el miércoles a las 2:00 a.m

# %%
# Elimina los pedidos duplicados
df_orders=df_orders.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
print(df_orders.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(df_orders['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos - Encontré 15 duplicaos que tenían el mismo mismo order_dow y order_hour_of_day, filtré los datos en base a esa columna y descubrir que los 15 duplicados se encontraban en los pedidos que se hicieron el miércoles a las 2:00 a.m. Borré los duplicados y me aseguré que no tuviera algún duplicado en user_id.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo con el análisis de duplicados

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(df_products.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
print(df_products['aisle_id'].duplicated().sum())
# Out:
# 49560

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
print(df_products['product_name'].str.upper().duplicated().sum())
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print(df_products[~df_products['product_name'].isna() & df_products['product_name'].duplicated(keep=False)])
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente trabajo! Solamente la verificación de duplicados te recomiendo hacerla sobre la varialble de nombre del producto. Para esto te puedes guiar del siguiente ejemplo:
#
#     products[(~products['product_name'].isna()) & products['product_name'].duplicated()]
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabaho verificando que no existen duplicados en la variable de producto!
#
# </div>

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. - Revise si existían filas duplicadas y observe que no hay. Después verifique si había ID de departamentos duplicados, de los cuales existen 49560 duplicados, esta información es correcta por lo que no la cambie. Después verifique si hay nombres duplicados de productos en mayúsculas, hay 1361 duplicados, al igual que aisle_id esta información es correcta por lo que no la cambie. Por último, verifique cuantos duplicados no “na” tenía usando notna.

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_departments.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print(df_departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. - Departments no tiene filas duplicadas ni duplicados de departments_id.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_aisles.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(df_aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. -  Aisles no tiene filas duplicadas ni duplicados de aisle_id.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(df_order_products.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(df_order_products[['order_id', 'product_id']].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. - Order Product no tiene filas duplicadas ni duplicados de order_id y product_id.

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(df_products['product_name'].isna().sum())
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. - Hay 1258 productos ausentes.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
productos_ausentes = df_products[df_products['product_name'].isna()]
pasillo_100 = (productos_ausentes['aisle_id'] == 100).all()
print(pasillo_100)
# Out:
# True

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. - Todos los productos asuentes estan relacionados con el pasillo con ID 100.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
productos_ausentes = df_products[df_products['product_name'].isna()]
departamento_21 = (productos_ausentes['department_id'] == 21).all()
print(departamento_21)
# Out:
# True

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. - Todos los productos asuentes estan relacionados con el departamento con ID 21.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

print(df_aisles[df_aisles['aisle_id'] == 100])
print()
print(df_departments[df_departments['department_id'] == 21])
# Out:
#     aisle_id    aisle
# 99       100  missing
#
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. - Tanto el pasillo con ID 100 como el departamento con ID 21 tienen su segunda columna con "missing".

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products['product_name'].fillna('Unknown', inplace=True)
print(df_products['product_name'].isna().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabajo!! Desarrollaste de manera excelente el análisis de valores faltantes y los llenaste con "unknown".
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(df_orders.isna().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
primer_pedido = df_orders.groupby('user_id')['order_number'].min()

valores_ausentes = df_orders[~df_orders['order_number'].isin(primer_pedido)].isna()

resultados = valores_ausentes.sum()

print(resultados)
# Out:
# order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. - Todos los valores ausentes encontrados fueron el primer pedido del cliente

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(df_order_products.isna().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(df_order_products['add_to_cart_order'].min())
print(df_order_products['add_to_cart_order'].max())
# Out:
# 1.0
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
ausente = df_order_products[df_order_products['add_to_cart_order'].isna()]

ausente_id = ausente[['order_id']]

print(ausente_id.head())
# Out:
#        order_id
# 737     2449164
# 9926    1968313
# 14394   2926893
# 16418   1717990
# 30114   1959075

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.

print(ausente.groupby('order_id')['product_id'].count())

print(ausente.groupby('order_id')['product_id'].count().min())
# Out:
# order_id
# 9310        1
# 61355      63
# 102236     31
# 129627      5
# 165801      6
#            ..
# 2999801     6
# 3125735    22
# 3308010    51
# 3347453     7
# 3383594     5
# Name: product_id, Length: 70, dtype: int64
# 1

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. - No todos los pedidos ausentes tienen más de 64 productos y el pedido mínimo tiene un producto.

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999)

df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].astype(int)

print(df_order_products['add_to_cart_order'].isna().sum())
print(df_order_products['add_to_cart_order'].dtype)
# Out:
# 0
# int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. - Reemplacé todos los valores ausentes por 999 y convertí la fila a entero.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente trabajo con este ejercicio, completaste de manera perfecta los valores ausentes con 999.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(df_orders[(df_orders['order_hour_of_day'] < 0) | (df_orders['order_hour_of_day'] > 23)]['order_hour_of_day'].count())
# Out:
# 0

# %%
print(df_orders[(df_orders['order_dow'] < 0) | (df_orders['order_dow'] > 6)]['order_dow'].count())
# Out:
# 0

# %% [markdown]
# Escribe aquí tus conclusiones - Los valores en las columnas 'order_hour_of_day' y 'order_dow' son razonables.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario Revisor</b> <a class="tocSkip"></a>
#
# Muy buena forma de revisar que los valores sean sensibles. Otra forma de hacerlo que puedes explorar más adeltante es el uso de la función  .value_counts().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario Revisor</b> <a class="tocSkip"></a>
#
# Excelente uso de la función value_counts() en los inciso siguientes!
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
ordenes_por_hora = df_orders.groupby('order_hour_of_day')['user_id'].nunique()

ordenes_por_hora.plot(marker='o', 
                      title='Número de personas que hacen pedidos dependiendo de la hora del día', 
                      xlabel='Hora del día (0-23)', 
                      ylabel='Número de personas', 
                      grid=True)
                     

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones - Las 4 de la mañana es la hora en la que menos personas hacen ordenes, mietras que a las 3 de la tarde es la hora en la que más personas hacen ordenes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario revisor</b> <a class="tocSkip"></a>
#
#
# Muy buen trabajo el desarrollar una gráfica para visualizar los resultados
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
compras_por_dia=df_orders.groupby('order_dow').size()

compras_por_dia.plot(kind='bar',
                     color='skyblue',
                     title='Número de pedidos por día de la semana',
                     xlabel='Día de la semana',
                     ylabel='Número de pedidos',
                     grid=True,
                     rot=360)


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones - La mayoría de las personas compran víveres los domingos.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
dias_espera = df_orders['days_since_prior_order'].dropna()

dias_espera.plot(kind='hist',
                 bins=50,  
                 title='Distribución del tiempo de espera hasta el siguiente pedido',
                 grid=True)
                
plt.xlabel('Días desde el último pedido')
plt.ylabel('Frecuencia')
plt.show()


print(dias_espera.min())
print(dias_espera.max())
# Out:
# 0.0
# 30.0

# %% [markdown]
# Escribe aquí tus conclusiones - El mayor numero de clientes espera 30 dias para volver a hacer otro pedidos, mientras existen clientes que hacen mas de un pedido el mismo dia.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario revisor</b> <a class="tocSkip"></a>
#
# En los tres ejercicios finales, complementaste con alguna gráfica que ayuda al análisis de los resultados

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miércoles = df_orders[df_orders['order_dow'] == 2]
pedidos_miércoles = miércoles.groupby('order_hour_of_day').size()

# %%
sábado = df_orders[df_orders['order_dow'] == 5]
pedidos_sábado = sábado.groupby('order_hour_of_day').size()

# %%
pedidos_miércoles.plot(kind='bar',
                       title='Distribución de horas de pedidos - Miércoles',
                       grid=True,
                       rot=360)
plt.xlabel('Hora del día (0-23)')
plt.ylabel('Número de pedidos')

plt.show()

# %%
pedidos_sábado.plot(kind='bar',
                    title='Distribución de horas de pedidos - Sábado',
                     grid=True,
                    rot=360)
                   
plt.xlabel('Hora del día (0-23)')
plt.ylabel('Número de pedidos')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones - Los pedidos los miercoles y sabados en base a las horas del dia se muestran iguales

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
pedidos_por_cliente = df_orders.groupby('user_id').size()
distribucion_pedidos = pedidos_por_cliente.value_counts().sort_index()

# %%
distribucion_pedidos.plot(kind='bar',title='Distribución del número de pedidos por cliente',grid=True,rot=360)

plt.xlabel('Número de pedidos')
plt.ylabel('Número de clientes')


plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones - El mayor numero de clientes hicieron solo un pedido.

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_order = df_order_products.groupby('product_id').size().reset_index(name='order_count')
top_20_products = product_order.merge(df_products[['product_id', 'product_name']], on='product_id')

# %%
top_20_products = top_20_products.sort_values('order_count', ascending=False).head(20)

# %%
print(top_20_products.reset_index(drop=True))
# Out:
#     product_id  order_count              product_name
# 0        24852        66050                    Banana
# 1        13176        53297    Bag of Organic Bananas
# 2        21137        37039      Organic Strawberries
# 3        21903        33971      Organic Baby Spinach
# 4        47209        29773      Organic Hass Avocado
# 5        47766        24689           Organic Avocado
# 6        47626        21495               Large Lemon
# 7        16797        20018              Strawberries
# 8        26209        19690                     Limes
# 9        27845        19600        Organic Whole Milk
# 10       27966        19197       Organic Raspberries
# 11       22935        15898      Organic Yellow Onion
# 12       24964        15292            Organic Garlic
# 13       45007        14584          Organic Zucchini
# 14       39275        13879       Organic Blueberries
# 15       49683        13675            Cucumber Kirby
# ...

# %% [markdown]
# Escribe aquí tus conclusiones - El producto mas vendido son platanos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen desarrollo de la sección. Desarrollaste de buena manera todos los análisis y lo complementaste con dos gráfica.
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
productos_por_pedido = df_order_products.groupby('order_id').size()

# %%
distribucion = productos_por_pedido.value_counts().sort_index().head(50)

# %%
distribucion.plot(kind='bar', figsize=(12, 6), rot=360)
plt.title('Distribución del número de productos por pedido')
plt.xlabel('Número de productos en el pedido')
plt.ylabel('Número de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones - La mayoria de los pedidos contienen 5 productos.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
top_20_reordered = df_order_products[df_order_products['reordered'] == 1]

# %%
top_20_reordered = top_20_reordered.groupby('product_id').size().reset_index(name='reorder_count')

# %%
top_20_reordered = top_20_reordered.merge(df_products[['product_id', 'product_name']], on='product_id').sort_values('reorder_count', ascending=False).head(20)

# %%
print(top_20_reordered.reset_index(drop=True))
# Out:
#     product_id  reorder_count              product_name
# 0        24852          55763                    Banana
# 1        13176          44450    Bag of Organic Bananas
# 2        21137          28639      Organic Strawberries
# 3        21903          26233      Organic Baby Spinach
# 4        47209          23629      Organic Hass Avocado
# 5        47766          18743           Organic Avocado
# 6        27845          16251        Organic Whole Milk
# 7        47626          15044               Large Lemon
# 8        27966          14748       Organic Raspberries
# 9        16797          13945              Strawberries
# 10       26209          13327                     Limes
# 11       22935          11145      Organic Yellow Onion
# 12       24964          10411            Organic Garlic
# 13       45007          10076          Organic Zucchini
# 14       49683           9538            Cucumber Kirby
# 15       28204           8989        Organic Fuji Apple
# ...

# %% [markdown]
# Escribe aquí tus conclusiones - El producto mas reordenado es platanos. Esta lista es muy parecida a la lista de los 20 productos más populares ya que en esa no se especifico si un producto era reordenado o no.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
total = df_order_products.groupby('product_id').size()
total_reordenados = df_order_products[df_order_products['reordered'] == 1].groupby('product_id').size()

# %%
result = (total_reordenados / total).reset_index(name='repeat_rate').merge(df_products[['product_id', 'product_name']], on='product_id')

# %%
print(result[['product_name', 'repeat_rate']])
print()
print(result[['product_name', 'repeat_rate']].describe())
# Out:
#                                             product_name  repeat_rate
# 0                             Chocolate Sandwich Cookies     0.564286
# 1                                       All-Seasons Salt          NaN
# 2                   Robust Golden Unsweetened Oolong Tea     0.738095
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...     0.510204
# 4                         Pure Coconut Water With Orange     0.500000
# ...                                                  ...          ...
# 45568                      HIGH PERFORMANCE ENERGY DRINK     0.800000
# 45569                      ORIGINAL PANCAKE & WAFFLE MIX     0.430556
# 45570    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR     0.416667
# 45571                             SPRING WATER BODY WASH     0.440000
# 45572                            BURRITO- STEAK & CHEESE     0.333333
#
# [45573 rows x 2 columns]
#
#         repeat_rate
# count  36228.000000
# mean       0.486458
# std        0.211266
# ...

# %% [markdown]
# Escribe aquí tus conclusiones - La proporción de las veces que se pide y que se vuelve a pedir un producto, tiene una media de 0.48, un maximo de 1 y un minimo de 0.010.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
total_products = df_order_products.groupby('order_id')['product_id'].nunique()
reordered_products = df_order_products[df_order_products['reordered'] == 1].groupby('order_id')['product_id'].nunique()
df_reorder_rate = reordered_products / total_products

# %%
print(df_reorder_rate)
print()
print(df_reorder_rate.describe())
# Out:
# order_id
# 4          0.923077
# 9          0.666667
# 11         1.000000
# 19         1.000000
# 20              NaN
#              ...
# 3421034    1.000000
# 3421053    1.000000
# 3421071    0.200000
# 3421077         NaN
# 3421079         NaN
# Name: product_id, Length: 450046, dtype: float64
#
# count    395819.000000
# mean          0.681691
# std           0.271629
# min           0.018519
# 25%           0.500000
# 50%           0.714286
# 75%           0.956522
# max           1.000000
# Name: product_id, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones - La proporción de las veces que un cliente pide un producto que ya habia pedido es similar a la anterior, aunque, los clientes parecen pedir mas productos que ya habian pedido a comparacion de la proporcion que un producto se pide y vuelve a pedir. Tiene una media de 0.65, un maximo de 1 y un minimo de 0.5.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_items = df_order_products[df_order_products['add_to_cart_order'] == 1]
top_20_first_items = first_items['product_id'].value_counts().head(20)

# %%
df_top_20 = top_20_first_items.reset_index().merge(df_products[['product_id', 'product_name']], on='product_id', how='left')
df_top_20.columns = ['product_id', 'first_item_count', 'product_name']

# %%
print(df_top_20)
# Out:
#     product_id  first_item_count  \
# 0        24852             15562
# 1        13176             11026
# 2        27845              4363
# 3        21137              3946
# 4        47209              3390
# 5        21903              3336
# 6        47766              3044
# 7        19660              2336
# 8        16797              2308
# 9        27966              2024
# 10       44632              1914
# 11       49235              1797
# 12       47626              1737
# 13         196              1733
# 14       38689              1397
# 15       26209              1370
# 16       12341              1340
# 17        5785              1310
# 18       27086              1309
# 19       22935              1246
#
#                                          product_name
# 0              Vitamin Code Raw D3 Vitamin Supplement
# 1                                             Unknown
# 2                                     Ambrosia Apples
# ...

# %% [markdown]
# Escribe aquí tus conclusiones - El producto que las personas ponen primero en sus carritos es Salted Caramel Cold Brew Coffee.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen desarrollo de los últimos  ejercicios de la sección. Desarrollaste de buena manera todos los análisis y lo complementaste con una gráfica.
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Primero, identificamos y completamos los valores ausentes e identificamos y eliminamos los valores duplicados.
# Al hacer un análisis detallado de los datos descubrimos, la frecuencia en las que los clientes hacen ordenes, 3 de la tarde en
# domingo, siendo la hora y día con mayores órdenes. Igualmente descubrimos que la mayor cantidad de clientes espera 30 días
# para hacer otra orden. Que la mayoría de los clientes piden un producto por orden. Y que los productos más pedidos
# y reordenados son plátanos.
